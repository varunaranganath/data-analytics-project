# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
hrdata=pd.read_csv('https://raw.githubusercontent.com/tkseneee/Dataset/dd7313e0c6487acd9ed7cd32b786782c7a1d3885/HR_data.csv')
hrdata.head(2)
# Out:
#    Age          Workclass  fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         Martial_Status        Occupation    Relationship    Race Gender  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country  Target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K

# %%
#check if there is any missing value

missing_values = hrdata.isnull().sum()
missing_values
# Out:
# Age                  0
# Workclass         2079
# fnlwgt               0
# Education            0
# Education_Num        0
# Martial_Status       0
# Occupation        2087
# Relationship         0
# Race                 0
# Gender               0
# Capital_Gain         0
# Capital_Loss         0
# Hours_per_week       0
# Country            656
# Target               0
# dtype: int64

# %%
#keep only the numeric values in one variable

numeric_data = hrdata.select_dtypes(include=[np.number])
numeric_data.head()
# Out:
#    Age  fnlwgt  Education_Num  Capital_Gain  Capital_Loss  Hours_per_week
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40

# %%
#Compute the Range and comment about the need of scaling for this dataset

range_data = numeric_data.max() - numeric_data.min()
range_data
# Out:
# Age                    73
# fnlwgt            1472420
# Education_Num          15
# Capital_Gain        99999
# Capital_Loss         4356
# Hours_per_week         98
# dtype: int64

# %%
#Perform standard scaling on the 'Area' column without using sklearn function


import pandas as pd
import numpy as np

# Generate a larger sample DataFrame with an 'Area' column for demonstration
np.random.seed(0)
area_data = np.random.randn(955) * 100 + 1000  # Random data with mean ~1000 and std ~100
df = pd.DataFrame({'Area': area_data})

# Calculate the mean and standard deviation of the 'Area' column
mean_area = df['Area'].mean()
std_area = df['Area'].std()

# Perform standard scaling
df['Area_scaled'] = (df['Area'] - mean_area) / std_area

print("Original 'Area' column:")
print(df['Area'].head())
print("\nStandard scaled 'Area' column:")
print(df['Area_scaled'].head())
# Out:
# Original 'Area' column:
# 0    1176.405235
# 1    1040.015721
# 2    1097.873798
# 3    1224.089320
# 4    1186.755799
# Name: Area, dtype: float64
#
# Standard scaled 'Area' column:
# 0    1.831160
# 1    0.459060
# 2    1.041121
# 3    2.310870
# 4    1.935289
# Name: Area_scaled, dtype: float64

# %%
#What is the min,max, mean and standard deviation of standard scaled data. Check these value for the scaled area column computed in the previous question

import pandas as pd
import numpy as np


np.random.seed(0)
area_data = np.random.randn(955) * 100 + 1000  
df = pd.DataFrame({'Area': area_data})


mean_area = df['Area'].mean()
std_area = df['Area'].std()


df['Area_scaled'] = (df['Area'] - mean_area) / std_area


min_value = df['Area_scaled'].min()
max_value = df['Area_scaled'].max()
mean_value = df['Area_scaled'].mean()
std_value = df['Area_scaled'].std()

print("Statistics of the standard scaled 'Area' column:")
print(f"Min: {min_value}")
print(f"Max: {max_value}")
print(f"Mean: {mean_value}")
print(f"Standard Deviation: {std_value}")
# Out:
# Statistics of the standard scaled 'Area' column:
# Min: -3.0079743018827694
# Max: 2.8324509732738603
# Mean: 6.566010097468989e-16
# Standard Deviation: 0.9999999999999994

# %%
#Apply Standard Scaler to all the column of the data using sklearn function
 
from sklearn.preprocessing import StandardScaler

# Apply Standard Scaler to all numeric columns
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numeric_data)

# Convert to DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=numeric_data.columns)
scaled_df.head()
# Out:
#         Age    fnlwgt  Education_Num  Capital_Gain  Capital_Loss  \
# 0  0.029050 -1.062152       1.134136      0.149031     -0.216957
# 1  0.834363 -1.007377       1.134136     -0.146177     -0.216957
# 2 -0.044160  0.243483      -0.420668     -0.146177     -0.216957
# 3  1.053994  0.423784      -1.198070     -0.146177     -0.216957
# 4 -0.776263  1.403866       1.134136     -0.146177     -0.216957
#
#    Hours_per_week
# 0       -0.034641
# 1       -2.218354
# 2       -0.034641
# 3       -0.034641
# 4       -0.034641

# %%
#Check whether all the scaled data mean and standard deviation is 0 and 1 respectively
scaled_desc = scaled_df.describe()

# Check mean and standard deviation
mean_std_check = scaled_desc.loc[['mean', 'std']]
mean_std_check
# Out:
#           Area  diameter     perimeter  circularity   homogeneity  \
# mean  0.000000  0.000000 -1.110223e-16     0.000000  1.110223e-16
# std   1.414214  1.414214  1.414214e+00     1.414214  1.414214e+00
#
#       compactness  homogeneity.1  3d bounding box dim rate  compactness2  \
# mean     0.000000       0.000000                  0.000000  1.110223e-16
# std      1.414214       1.414214                  1.414214  1.414214e+00
#
#       clbp mean  ...  DC constant    energy   skew inside  kurtosis inside  \
# mean   0.000000  ...     0.000000  0.000000 -5.551115e-17         0.000000
# std    1.414214  ...     1.414214  1.414214  1.414214e+00         1.414214
#
#       moment 2           MIP      moment 5      moment 6  moment 7  \
# mean  0.000000 -4.440892e-16 -1.110223e-16 -1.110223e-16  0.000000
# std   1.414214  1.414214e+00  1.414214e+00  1.414214e+00  1.414214
#
#       x-y plane bb rate
# mean       2.692291e-14
# std        1.414214e+00
#
# [2 rows x 23 columns]

# %%
# standard deviation
import pandas as pd
from sklearn.preprocessing import RobustScaler

# Sample DataFrame with the given values
data = {
    'Area': [5.008001, 0.150511],
    'diameter': [0.416049, -0.299221],
    'perimeter': [2.259582, 0.383373],
    'circularity': [0.980681, 0.540147],
    'homogeneity': [2.609209, -0.422658],
    'compactness': [0.562497, 1.248071],
    'homogeneity.1': [1.706215, 1.362027],
    '3d bounding box dim rate': [1.886212, 1.580743],
    'compactness2': [-0.106281, -0.218941],
    'clbp mean': [0.670617, -0.283798],
    'euler point': [1.301341, 2.430487],
    'x-y projection compactness': [2.75272, 1.31084],
    'min value inside': [2.800246, 2.808361],
    'DC constant': [1.320346, 1.323584],
    'energy': [7.158378, 3.009626],
    'skew inside': [1.07347, 0.426552],
    'kurtosis inside': [2.372627, 0.026884],
    'moment 2': [0.504931, 1.127144],
    'MIP': [0.907926, 1.405554],
    'moment 5': [0.421853, 1.304627],
    'moment 6': [0.138351, 1.01741],
    'moment 7': [22.316072, 0.247895],
    'x-y plane bb rate': [2.74225, 2.72576]
}

df_original = pd.DataFrame(data)

# Initialize the RobustScaler
scaler = RobustScaler()

# Fit and transform the data to scale it
scaled_data = scaler.fit_transform(df_original)

# Convert the scaled data back to a DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=df_original.columns)

# Checking mean and standard deviation of the scaled data
means = scaled_df.mean()
stds = scaled_df.std()

print("Means of scaled data:")
print(means)
print("\nStandard deviations of scaled data:")
print(stds)
# Out:
# Means of scaled data:
# Area                          0.000000e+00
# diameter                      0.000000e+00
# perimeter                    -1.110223e-16
# circularity                   0.000000e+00
# homogeneity                   1.110223e-16
# compactness                   0.000000e+00
# homogeneity.1                 0.000000e+00
# 3d bounding box dim rate      0.000000e+00
# compactness2                  1.110223e-16
# clbp mean                     0.000000e+00
# euler point                  -2.220446e-16
# x-y projection compactness    1.665335e-16
# min value inside              0.000000e+00
# DC constant                   0.000000e+00
# energy                        0.000000e+00
# skew inside                  -5.551115e-17
# kurtosis inside               0.000000e+00
# moment 2                      0.000000e+00
# MIP                          -4.440892e-16
# moment 5                     -1.110223e-16
# moment 6                     -1.110223e-16
# ...

# %%
8)
import pandas as pd
from sklearn.preprocessing import RobustScaler

# Sample DataFrame with the given values
data = {
    'Area': [61.8750, 14.0625],
    'diameter': [12.0, 7.5],
    'perimeter': [32.077140, 16.749615],
    'circularity': [0.755673, 0.629887],
    'homogeneity': [449.71875, 56.30625],
    'compactness': [1.345392, 1.615692],
    'homogeneity.1': [1.0, 0.9],
    '3d bounding box dim rate': [0.758333, 0.693333],
    'compactness2': [2.339759, 2.105107],
    'clbp mean': [14.65, 7.85],
    'euler point': [2.0, 3.0],
    'x-y projection compactness': [0.772116, 0.514698],
    'min value inside': [19.746809, 19.778557],
    'DC constant': [1.001611, 1.002350],
    'energy': [10.149219, 5.401159],
    'skew inside': [0.462735, 0.182834],
    'kurtosis inside': [3.076589, 1.547886],
    'moment 2': [238.76445, 313.56543],
    'MIP': [276.318695, 318.816223],
    'moment 5': [65971.18750, 99969.98438],
    'moment 6': [15752872.0, 31347990.0],
    'moment 7': [368197.28130, 13273.56641],
    'x-y plane bb rate': [19.111872, 19.048378]
}

df_original = pd.DataFrame(data)

# Initialize the RobustScaler
scaler = RobustScaler()

# Fit and transform the data to scale it
scaled_data = scaler.fit_transform(df_original)

# Convert the scaled data back to a DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=df_original.columns)

# Checking mean and standard deviation of the scaled data
means = scaled_df.mean()
stds = scaled_df.std()

print("Means of scaled data:")
print(means)
print("\nStandard deviations of scaled data:")
print(stds)

# Inverse transform the scaled data back to the original form
inverse_data = scaler.inverse_transform(scaled_data)
# Out:
# Means of scaled data:
# Area                          0.000000e+00
# diameter                      0.000000e+00
# perimeter                     0.000000e+00
# circularity                   8.881784e-16
# homogeneity                   5.551115e-17
# compactness                   8.326673e-16
# homogeneity.1                 1.110223e-15
# 3d bounding box dim rate      1.720846e-15
# compactness2                  1.887379e-15
# clbp mean                     0.000000e+00
# euler point                   0.000000e+00
# x-y projection compactness   -4.440892e-16
# min value inside              0.000000e+00
# DC constant                  -3.004264e-13
# energy                        0.000000e+00
# skew inside                  -2.220446e-16
# kurtosis inside              -3.330669e-16
# moment 2                      0.000000e+00
# MIP                           0.000000e+00
# moment 5                      4.440892e-16
# moment 6                      0.000000e+00
# ...

# %%
9)
import pandas as pd
from sklearn.preprocessing import RobustScaler

# Sample DataFrame with the given values
data = {
    'Area': [0.357093, 0.060098],
    'diameter': [0.340021, 0.181626],
    'perimeter': [0.419502, 0.184346],
    'circularity': [0.725792, 0.591221],
    'homogeneity': [0.226615, 0.020532],
    'compactness': [0.550961, 0.720749],
    'homogeneity.1': [1.0, 0.888393],
    '3d bounding box dim rate': [0.763753, 0.688184],
    'compactness2': [0.210002, 0.184940],
    'clbp mean': [0.327372, 0.150090],
    'euler point': [0.545455, 0.636364],
    'x-y projection compactness': [0.688153, 0.432865],
    'min value inside': [0.606251, 0.607397],
    'DC constant': [0.977068, 0.978100],
    'energy': [1.0, 0.506805],
    'skew inside': [0.698834, 0.573685],
    'kurtosis inside': [0.683406, 0.267713],
    'moment 2': [0.51166, 0.69597],
    'MIP': [0.634954, 0.761435],
    'moment 5': [0.479095, 0.769759],
    'moment 6': [0.279127, 0.570101],
    'moment 7': [0.233187, 0.007613],
    'x-y plane bb rate': [0.635024, 0.632536]
}

df_original = pd.DataFrame(data)

# Initialize the RobustScaler
scaler = RobustScaler()

# Fit and transform the data to scale it
scaled_data = scaler.fit_transform(df_original)

# Convert the scaled data back to a DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=df_original.columns)

# Checking mean and standard deviation of the scaled data
means = scaled_df.mean()
stds = scaled_df.std()

print("Means of scaled data:")
print(means)
print("\nStandard deviations of scaled data:")
print(stds)

# Inverse transform the scaled data back to the original form
inverse_data = scaler.inverse_transform(scaled_data)

# Convert to DataFrame
inverse_df = pd.DataFrame(inverse_data, columns=df_original.columns)

print("\nOriginal DataFrame:")
print(df_original.head())

print("\nInverse Transformed DataFrame:")
print(inverse_df.head())
# Out:
# Means of scaled data:
# Area                          0.000000e+00
# diameter                      3.330669e-16
# perimeter                     2.220446e-16
# circularity                   0.000000e+00
# homogeneity                   0.000000e+00
# compactness                  -6.661338e-16
# homogeneity.1                 0.000000e+00
# 3d bounding box dim rate      0.000000e+00
# compactness2                 -1.110223e-15
# clbp mean                     0.000000e+00
# euler point                   1.221245e-15
# x-y projection compactness   -2.220446e-16
# min value inside             -9.686696e-14
# DC constant                   0.000000e+00
# energy                        0.000000e+00
# skew inside                   0.000000e+00
# kurtosis inside               0.000000e+00
# moment 2                      0.000000e+00
# MIP                          -8.881784e-16
# moment 5                      1.665335e-16
# moment 6                      0.000000e+00
# ...

# %%
10)
from sklearn.preprocessing import RobustScaler

# Initialize RobustScaler
robust_scaler = RobustScaler()

# Fit and transform the numeric data
robust_scaled_data = robust_scaler.fit_transform(numeric_data)

# Convert to DataFrame
robust_scaled_df = pd.DataFrame(robust_scaled_data, columns=numeric_data.columns)

# Display the first few rows of the robust scaled data
robust_scaled_df.head()
# Out:
#     Age    fnlwgt  Education_Num  Capital_Gain  Capital_Loss  Hours_per_week
# 0  0.10 -0.841482       1.000000        2174.0           0.0             0.0
# 1  0.65 -0.793073       1.000000           0.0           0.0            -5.4
# 2  0.05  0.312399      -0.333333           0.0           0.0             0.0
# 3  0.80  0.471744      -1.000000           0.0           0.0             0.0
# 4 -0.45  1.337911       1.000000           0.0           0.0             0.0
